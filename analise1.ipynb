# %% [markdown]
# <!-- Lab1 - Desenvolvido por Silmara Basso -->
# # <font color='Green'>Evolução das Vendas ao Longo do Tempo</font>
# ## <font color='Green'>Storytelling, Dashboards e Técnicas de Apresentação Para Cientistas de Dados</font>
# ## <font color='Green'>Lab1 - Parte 1</font>
# ### <font color='Green'>Engajando a Audiência Através de História Sobre a Análise dos Dados</font>

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
pip install -r requirements.txt
# Out:
# Collecting anyio==4.9.0 (from -r requirements.txt (line 1))
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: appnope==0.1.4 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (0.1.4)
# Collecting argon2-cffi==25.1.0 (from -r requirements.txt (line 3))
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting argon2-cffi-bindings==21.2.0 (from -r requirements.txt (line 4))
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Collecting arrow==1.3.0 (from -r requirements.txt (line 5))
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: asttokens==3.0.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (3.0.0)
# Collecting async-lru==2.0.5 (from -r requirements.txt (line 7))
#   Using cached async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting attrs==25.3.0 (from -r requirements.txt (line 8))
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting babel==2.17.0 (from -r requirements.txt (line 9))
#   Using cached babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting beautifulsoup4==4.13.4 (from -r requirements.txt (line 10))
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach==6.2.0 (from -r requirements.txt (line 11))
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting certifi==2025.7.14 (from -r requirements.txt (line 12))
#   Using cached certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting cffi==1.17.1 (from -r requirements.txt (line 13))
#   Downloading cffi-1.17.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting charset-normalizer==3.4.2 (from -r requirements.txt (line 14))
#   Downloading charset_normalizer-3.4.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting comm==0.2.2 (from -r requirements.txt (line 15))
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting contourpy==1.3.2 (from -r requirements.txt (line 16))
#   Downloading contourpy-1.3.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler==0.12.1 (from -r requirements.txt (line 17))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting debugpy==1.8.14 (from -r requirements.txt (line 18))
#   Downloading debugpy-1.8.14-cp313-cp313-macosx_14_0_universal2.whl.metadata (1.3 kB)
# Requirement already satisfied: decorator==5.2.1 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 19)) (5.2.1)
# Collecting defusedxml==0.7.1 (from -r requirements.txt (line 20))
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: executing==2.2.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 21)) (2.2.0)
# Collecting fastjsonschema==2.21.1 (from -r requirements.txt (line 22))
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting fonttools==4.58.5 (from -r requirements.txt (line 23))
#   Downloading fonttools-4.58.5-cp313-cp313-macosx_10_13_universal2.whl.metadata (106 kB)
# Collecting fqdn==1.5.1 (from -r requirements.txt (line 24))
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting h11==0.16.0 (from -r requirements.txt (line 25))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting httpcore==1.0.9 (from -r requirements.txt (line 26))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting httpx==0.28.1 (from -r requirements.txt (line 27))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting idna==3.10 (from -r requirements.txt (line 28))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting ipykernel==6.29.5 (from -r requirements.txt (line 29))
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: ipython==9.4.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 30)) (9.4.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 31)) (1.1.1)
# Collecting ipywidgets==8.1.7 (from -r requirements.txt (line 32))
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting isoduration==20.11.0 (from -r requirements.txt (line 33))
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jedi==0.19.2 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 34)) (0.19.2)
# Collecting Jinja2==3.1.6 (from -r requirements.txt (line 35))
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting json5==0.12.0 (from -r requirements.txt (line 36))
#   Using cached json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Collecting jsonpointer==3.0.0 (from -r requirements.txt (line 37))
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonschema==4.24.0 (from -r requirements.txt (line 38))
#   Using cached jsonschema-4.24.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting jsonschema-specifications==2025.4.1 (from -r requirements.txt (line 39))
#   Using cached jsonschema_specifications-2025.4.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting jupyter==1.1.1 (from -r requirements.txt (line 40))
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting jupyter-console==6.6.3 (from -r requirements.txt (line 41))
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-events==0.12.0 (from -r requirements.txt (line 42))
#   Using cached jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-lsp==2.2.5 (from -r requirements.txt (line 43))
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter_client==8.6.3 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 44)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.8.1 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 45)) (5.8.1)
# Collecting jupyter_server==2.16.0 (from -r requirements.txt (line 46))
#   Using cached jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyter_server_terminals==0.5.3 (from -r requirements.txt (line 47))
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting jupyterlab==4.4.4 (from -r requirements.txt (line 48))
#   Using cached jupyterlab-4.4.4-py3-none-any.whl.metadata (16 kB)
# Collecting jupyterlab_pygments==0.3.0 (from -r requirements.txt (line 49))
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting jupyterlab_server==2.27.3 (from -r requirements.txt (line 50))
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab_widgets==3.0.15 (from -r requirements.txt (line 51))
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting kiwisolver==1.4.8 (from -r requirements.txt (line 52))
#   Downloading kiwisolver-1.4.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Collecting MarkupSafe==3.0.2 (from -r requirements.txt (line 53))
#   Downloading MarkupSafe-3.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting matplotlib==3.10.3 (from -r requirements.txt (line 54))
#   Downloading matplotlib-3.10.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 55)) (0.1.7)
# Collecting mistune==3.1.3 (from -r requirements.txt (line 56))
#   Using cached mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient==0.10.2 (from -r requirements.txt (line 57))
#   Using cached nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting nbconvert==7.16.6 (from -r requirements.txt (line 58))
#   Using cached nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat==5.10.4 (from -r requirements.txt (line 59))
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 60)) (1.6.0)
# Collecting notebook==7.4.4 (from -r requirements.txt (line 61))
#   Using cached notebook-7.4.4-py3-none-any.whl.metadata (10 kB)
# Collecting notebook_shim==0.2.4 (from -r requirements.txt (line 62))
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy==2.3.1 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 63)) (2.3.1)
# Collecting overrides==7.7.0 (from -r requirements.txt (line 64))
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging==25.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 65)) (25.0)
# Collecting pandas==2.3.1 (from -r requirements.txt (line 66))
#   Downloading pandas-2.3.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting pandocfilters==1.5.1 (from -r requirements.txt (line 67))
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: parso==0.8.4 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 68)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 69)) (4.9.0)
# Collecting pillow==11.3.0 (from -r requirements.txt (line 70))
#   Downloading pillow-11.3.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: platformdirs==4.3.8 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 71)) (4.3.8)
# Collecting prometheus_client==0.22.1 (from -r requirements.txt (line 72))
#   Using cached prometheus_client-0.22.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: prompt_toolkit==3.0.51 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 73)) (3.0.51)
# Requirement already satisfied: psutil==7.0.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 74)) (7.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 75)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 76)) (0.2.3)
# Collecting pycparser==2.22 (from -r requirements.txt (line 77))
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: Pygments==2.19.2 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 78)) (2.19.2)
# Collecting pyparsing==3.2.3 (from -r requirements.txt (line 79))
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 80)) (2.9.0.post0)
# Collecting python-json-logger==3.3.0 (from -r requirements.txt (line 81))
#   Using cached python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pytz==2025.2 (from -r requirements.txt (line 82))
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting PyYAML==6.0.2 (from -r requirements.txt (line 83))
#   Downloading PyYAML-6.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting pyzmq==27.0.0 (from -r requirements.txt (line 84))
#   Using cached pyzmq-27.0.0-cp312-abi3-macosx_10_15_universal2.whl.metadata (6.0 kB)
# Collecting referencing==0.36.2 (from -r requirements.txt (line 85))
#   Using cached referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting requests==2.32.4 (from -r requirements.txt (line 86))
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting rfc3339-validator==0.1.4 (from -r requirements.txt (line 87))
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator==0.1.1 (from -r requirements.txt (line 88))
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting rpds-py==0.26.0 (from -r requirements.txt (line 89))
#   Downloading rpds_py-0.26.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting seaborn==0.13.2 (from -r requirements.txt (line 90))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting Send2Trash==1.8.3 (from -r requirements.txt (line 91))
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting setuptools==78.1.1 (from -r requirements.txt (line 92))
#   Using cached setuptools-78.1.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: six==1.17.0 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 93)) (1.17.0)
# Collecting sniffio==1.3.1 (from -r requirements.txt (line 94))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting soupsieve==2.7 (from -r requirements.txt (line 95))
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: stack-data==0.6.3 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 96)) (0.6.3)
# Collecting terminado==0.18.1 (from -r requirements.txt (line 97))
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting tinycss2==1.4.0 (from -r requirements.txt (line 98))
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tornado==6.5.1 (from -r requirements.txt (line 99))
#   Using cached tornado-6.5.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (2.8 kB)
# Requirement already satisfied: traitlets==5.14.3 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 100)) (5.14.3)
# Collecting types-python-dateutil==2.9.0.20250708 (from -r requirements.txt (line 101))
#   Using cached types_python_dateutil-2.9.0.20250708-py3-none-any.whl.metadata (1.9 kB)
# Collecting typing_extensions==4.14.1 (from -r requirements.txt (line 102))
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting tzdata==2025.2 (from -r requirements.txt (line 103))
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting uri-template==1.3.0 (from -r requirements.txt (line 104))
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting urllib3==2.5.0 (from -r requirements.txt (line 105))
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /Users/silmarabasso/.pyenv/versions/3.13.6/lib/python3.13/site-packages (from -r requirements.txt (line 106)) (0.2.13)
# Collecting webcolors==24.11.1 (from -r requirements.txt (line 107))
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting webencodings==0.5.1 (from -r requirements.txt (line 108))
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting websocket-client==1.8.0 (from -r requirements.txt (line 109))
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting wheel==0.45.1 (from -r requirements.txt (line 110))
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting widgetsnbextension==4.0.14 (from -r requirements.txt (line 111))
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached babel-2.17.0-py3-none-any.whl (10.2 MB)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Using cached certifi-2025.7.14-py3-none-any.whl (162 kB)
# Downloading cffi-1.17.1-cp313-cp313-macosx_11_0_arm64.whl (178 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-macosx_10_13_universal2.whl (199 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading contourpy-1.3.2-cp313-cp313-macosx_11_0_arm64.whl (255 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading debugpy-1.8.14-cp313-cp313-macosx_14_0_universal2.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 33.8 MB/s  0:00:00
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading fonttools-4.58.5-cp313-cp313-macosx_10_13_universal2.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 15.2 MB/s  0:00:00
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached json5-0.12.0-py3-none-any.whl (36 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached jsonschema-4.24.0-py3-none-any.whl (88 kB)
# Using cached jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server-2.16.0-py3-none-any.whl (386 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached jupyterlab-4.4.4-py3-none-any.whl (12.3 MB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading kiwisolver-1.4.8-cp313-cp313-macosx_11_0_arm64.whl (65 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-macosx_11_0_arm64.whl (12 kB)
# Downloading matplotlib-3.10.3-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 8.0 MB/s  0:00:00m eta 0:00:01
# Using cached mistune-3.1.3-py3-none-any.whl (53 kB)
# Using cached nbclient-0.10.2-py3-none-any.whl (25 kB)
# Using cached nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached notebook-7.4.4-py3-none-any.whl (14.3 MB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pandas-2.3.1-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 78.4 MB/s  0:00:00
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading pillow-11.3.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 65.0 MB/s  0:00:00
# Using cached prometheus_client-0.22.1-py3-none-any.whl (58 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading PyYAML-6.0.2-cp313-cp313-macosx_11_0_arm64.whl (171 kB)
# Using cached pyzmq-27.0.0-cp312-abi3-macosx_10_15_universal2.whl (1.3 MB)
# Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rpds_py-0.26.0-cp313-cp313-macosx_11_0_arm64.whl (350 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached setuptools-78.1.1-py3-none-any.whl (1.3 MB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Using cached tornado-6.5.1-cp39-abi3-macosx_10_9_universal2.whl (441 kB)
# Using cached types_python_dateutil-2.9.0.20250708-py3-none-any.whl (17 kB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: webencodings, pytz, fastjsonschema, widgetsnbextension, wheel, websocket-client, webcolors, urllib3, uri-template, tzdata, typing_extensions, types-python-dateutil, tornado, tinycss2, soupsieve, sniffio, setuptools, Send2Trash, rpds-py, rfc3986-validator, rfc3339-validator, pyzmq, PyYAML, python-json-logger, pyparsing, pycparser, prometheus_client, pillow, pandocfilters, overrides, mistune, MarkupSafe, kiwisolver, jupyterlab_widgets, jupyterlab_pygments, jsonpointer, json5, idna, h11, fqdn, fonttools, defusedxml, debugpy, cycler, contourpy, comm, charset-normalizer, certifi, bleach, babel, attrs, async-lru, terminado, requests, referencing, pandas, matplotlib, Jinja2, httpcore, cffi, beautifulsoup4, arrow, anyio, seaborn, jupyter_server_terminals, jsonschema-specifications, isoduration, ipywidgets, ipykernel, httpx, argon2-cffi-bindings, jupyter-console, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter_server, notebook_shim, jupyterlab_server, jupyter-lsp, jupyterlab, notebook, jupyter
#   Attempting uninstall: tornado━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/85 [urllib3]
#     Found existing installation: tornado 6.5.2━━━━━━━━━━━━━━━━  7/85 [urllib3]
#     Uninstalling tornado-6.5.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/85 [urllib3]
#       Successfully uninstalled tornado-6.5.2━━━━━━━━━━━━━━━━━━  7/85 [urllib3]
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/85 [tornado]
#     Found existing installation: setuptools 80.9.0━━━━━━━━━━━━ 12/85 [tornado]
#     Uninstalling setuptools-80.9.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/85 [tornado]
#       Successfully uninstalled setuptools-80.9.0━━━━━━━━━━━━━━━━━━ 16/85 [setuptools]
#   Attempting uninstall: pyzmq━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/85 [setuptools]
#     Found existing installation: pyzmq 27.0.1━━━━━━━━━━━━━━━━━ 16/85 [setuptools]
#     Uninstalling pyzmq-27.0.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/85 [setuptools]
#       Successfully uninstalled pyzmq-27.0.1━━━━━━━━━━━━━━━━━━━ 16/85 [setuptools]
#   Attempting uninstall: debugpy╸━━━━━━━━━━━━━━━━━━━━━ 40/85 [fonttools]
#     Found existing installation: debugpy 1.8.16━━━━━━━━━━━━━━━ 40/85 [fonttools]
#     Uninstalling debugpy-1.8.16:━━━━━━━━━━━━━━━━━━━━━ 40/85 [fonttools]
#       Successfully uninstalled debugpy-1.8.16━━━━━━━━━━━━━━━━━ 40/85 [fonttools]
#   Attempting uninstall: comm╸━━━━━━━━━━━━━━━━━━━━ 42/85 [debugpy]
#     Found existing installation: comm 0.2.3━━━━━━━━━━━━━━━━━━━ 42/85 [debugpy]
#     Uninstalling comm-0.2.3:╸━━━━━━━━━━━━━━━━━━━━ 42/85 [debugpy]
#       Successfully uninstalled comm-0.2.3m━━━━━━━━━━━━━━━━━━━━ 42/85 [debugpy]
#   Attempting uninstall: ipykernel━━━━━━╸━━━━━━━━ 67/85 [ipywidgets]
#     Found existing installation: ipykernel 6.30.1━━━━━━━━ 67/85 [ipywidgets]
#     Uninstalling ipykernel-6.30.1:━╸━━━━━━━━ 67/85 [ipywidgets]
#       Successfully uninstalled ipykernel-6.30.10m━━━━━━━━ 67/85 [ipywidgets]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85/85 [jupyter][notebook]jupyterlab]ver]
# Successfully installed Jinja2-3.1.6 MarkupSafe-3.0.2 PyYAML-6.0.2 Send2Trash-1.8.3 anyio-4.9.0 argon2-cffi-25.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 attrs-25.3.0 babel-2.17.0 beautifulsoup4-4.13.4 bleach-6.2.0 certifi-2025.7.14 cffi-1.17.1 charset-normalizer-3.4.2 comm-0.2.2 contourpy-1.3.2 cycler-0.12.1 debugpy-1.8.14 defusedxml-0.7.1 fastjsonschema-2.21.1 fonttools-4.58.5 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 ipykernel-6.29.5 ipywidgets-8.1.7 isoduration-20.11.0 json5-0.12.0 jsonpointer-3.0.0 jsonschema-4.24.0 jsonschema-specifications-2025.4.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter_server-2.16.0 jupyter_server_terminals-0.5.3 jupyterlab-4.4.4 jupyterlab_pygments-0.3.0 jupyterlab_server-2.27.3 jupyterlab_widgets-3.0.15 kiwisolver-1.4.8 matplotlib-3.10.3 mistune-3.1.3 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.4.4 notebook_shim-0.2.4 overrides-7.7.0 pandas-2.3.1 pandocfilters-1.5.1 pillow-11.3.0 prometheus_client-0.22.1 pycparser-2.22 pyparsing-3.2.3 python-json-logger-3.3.0 pytz-2025.2 pyzmq-27.0.0 referencing-0.36.2 requests-2.32.4 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.26.0 seaborn-0.13.2 setuptools-78.1.1 sniffio-1.3.1 soupsieve-2.7 terminado-0.18.1 tinycss2-1.4.0 tornado-6.5.1 types-python-dateutil-2.9.0.20250708 typing_extensions-4.14.1 tzdata-2025.2 uri-template-1.3.0 urllib3-2.5.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 wheel-0.45.1 widgetsnbextension-4.0.14
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
import warnings
warnings.filterwarnings('ignore')

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Silmara Basso"
# Out:
# Author: Silmara Basso

# %% [markdown]
# ## Carregando os Dados

# %%
# Carrega o dataset
df_vendas = pd.read_csv('dataset1.csv')

# %%
# Shape
df_vendas.shape
# Out:
# (116581, 53)

# %%
# Amostra dos dados
df_vendas.head()
# Out:
#   order_id                         order_id3  \
# 0  ON34305  e481f51cbdc54678b7cc49136f2d6af7
# 1  ON34305  e481f51cbdc54678b7cc49136f2d6af7
# 2  ON34305  e481f51cbdc54678b7cc49136f2d6af7
# 3  ON40291  128e10d95713541c87cd1a2e48201934
# 4  ON74313  0e7e841ddf8f8f2de2bad69267ecfbcf
#
#                        customer_id3 order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 2  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 3  a20e8105f23924cd00833fd87daa0831    delivered      2017-08-15 18:29:31
# 4  26c7ac168e1433912a51b924fbd34d34    delivered      2017-08-02 18:24:47
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-10-02 11:07:15          2017-10-04 19:55:00
# 1  2017-10-02 11:07:15          2017-10-04 19:55:00
# 2  2017-10-02 11:07:15          2017-10-04 19:55:00
# 3  2017-08-15 20:05:16          2017-08-17 15:28:33
# 4  2017-08-02 18:43:15          2017-08-04 17:35:43
#
#   order_delivered_customer_date order_estimated_delivery_date  order_item_id  \
# 0           2017-10-10 21:25:13           2017-10-18 00:00:00            1.0
# 1           2017-10-10 21:25:13           2017-10-18 00:00:00            1.0
# 2           2017-10-10 21:25:13           2017-10-18 00:00:00            1.0
# 3           2017-08-18 14:44:43           2017-08-28 00:00:00            1.0
# 4           2017-08-07 18:30:01           2017-08-15 00:00:00            1.0
#
#    ... seller_city seller_state product_category_name_english  \
# 0  ...        Maua           SP                    housewares
# 1  ...        Maua           SP                    housewares
# 2  ...        Maua           SP                    housewares
# 3  ...        Maua           SP                    housewares
# 4  ...        Maua           SP                    housewares
#
#    review_response_time  order_purchase_year  order_purchase_month  \
# 0                   1.0                 2017                    10
# 1                   1.0                 2017                    10
# 2                   1.0                 2017                    10
# 3                   1.0                 2017                     8
# 4                   0.0                 2017                     8
#
#   order_purchase_dayofweek  order_purchase_hour  order_purchase_day  \
# 0                        0                   10                 Mon
# 1                        0                   10                 Mon
# 2                        0                   10                 Mon
# 3                        1                   18                 Tue
# 4                        2                   18                 Wed
#
#   order_purchase_mon
# 0                Oct
# 1                Oct
# 2                Oct
# 3                Aug
# 4                Aug
#
# [5 rows x 53 columns]

# %%
# Info
df_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116581 entries, 0 to 116580
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       116581 non-null  object
#  1   order_id3                      116581 non-null  object
#  2   customer_id3                   116581 non-null  object
#  3   order_status                   116581 non-null  object
#  4   order_purchase_timestamp       116581 non-null  object
#  5   order_approved_at              116581 non-null  object
#  6   order_delivered_carrier_date   116581 non-null  object
#  7   order_delivered_customer_date  116581 non-null  object
#  8   order_estimated_delivery_date  116581 non-null  object
#  9   order_item_id                  116581 non-null  float64
#  10  product_id3                    116581 non-null  object
#  11  seller_id3                     116581 non-null  object
#  12  shipping_limit_date            116581 non-null  object
#  13  price                          116581 non-null  float64
#  14  freight_value                  116581 non-null  float64
#  15  payment_sequential             116581 non-null  int64
#  16  payment_type                   116581 non-null  object
#  17  payment_installments           116581 non-null  int64
#  18  payment_value                  116581 non-null  float64
#  19  review_id                      116581 non-null  object
#  20  review_id3                     116581 non-null  object
#  21  review_score                   116581 non-null  float64
#  22  review_comment_title           13996 non-null   object
#  23  review_comment_message         49878 non-null   object
#  24  review_creation_date           116578 non-null  object
#  25  review_answer_timestamp        116578 non-null  object
#  26  product_id                     116581 non-null  object
#  27  product_category_name          116581 non-null  object
#  28  product_name_lenght            116581 non-null  float64
#  29  product_description_lenght     116581 non-null  float64
#  30  product_photos_qty             116581 non-null  float64
#  31  product_weight_g               116580 non-null  float64
#  32  product_length_cm              116580 non-null  float64
#  33  product_height_cm              116580 non-null  float64
#  34  product_width_cm               116580 non-null  float64
#  35  customer_id                    116581 non-null  int64
#  36  customer_unique_id             116581 non-null  object
#  37  customer_uniqueid3             116581 non-null  object
#  38  customer_zip_code_prefix       116581 non-null  int64
#  39  customer_city                  116581 non-null  object
#  40  customer_state                 116581 non-null  object
#  41  seller_id                      116581 non-null  object
#  42  seller_zip_code_prefix         116581 non-null  int64
#  43  seller_city                    116581 non-null  object
#  44  seller_state                   116581 non-null  object
#  45  product_category_name_english  116581 non-null  object
#  46  review_response_time           116578 non-null  float64
#  47  order_purchase_year            116581 non-null  int64
#  48  order_purchase_month           116581 non-null  int64
#  49  order_purchase_dayofweek       116581 non-null  int64
#  50  order_purchase_hour            116581 non-null  int64
#  51  order_purchase_day             116581 non-null  object
#  52  order_purchase_mon             116581 non-null  object
# dtypes: float64(13), int64(9), object(31)
# memory usage: 47.1+ MB

# %% [markdown]
# ## Funções Customizadas Para Visualização dos Dados
#
# Você sempre tem a opção de criar funções Python para personalizar ou customizar seus gráficos.

# %%
# Função para formatar os eixos de um gráfico (ax) com opção para borda direita
def vendas_format_spines(ax, right_border = True):
    
    # Define a cor da borda inferior
    ax.spines['bottom'].set_color("#000000")  
    
    # Define a cor da borda esquerda
    ax.spines['left'].set_color('#000000')  
    
    # Torna a borda superior invisível
    ax.spines['top'].set_visible(False)   
    
    # Verifica se a borda direita deve ser visível
    if right_border:       
        
        # Se sim, define a cor da borda direita como branco
        ax.spines['right'].set_color('#FFFFFF')  
        
    else:
        
        # Se não, também define a cor da borda direita como branco
        ax.spines['right'].set_color('#FFFFFF') 
    
    # Define a cor de fundo do gráfico como branco
    ax.patch.set_facecolor('#FFFFFF')

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/colormap_reference.html

# %%
# Define uma função para criar um gráfico de contagem (count plot)
def vendas_count_plot(feature, df, colors = 'Wistia_r', hue = False, ax = None, title = ''):
    
    # Inicializa uma variável com o número total de entradas no dataframe
    ncount = len(df)
    
    # Cria um gráfico de contagem com ou sem uma variável de agrupamento (hue)
    if hue != False:
        ax = sns.countplot(x = feature, data = df, palette = colors, hue = hue, ax = ax)
    else:
        ax = sns.countplot(x = feature, data = df, palette = colors, ax = ax)
        
    # Chama a função para formatar as bordas do gráfico
    vendas_format_spines(ax)

    # Calcula e anota (imprime no gráfico) a porcentagem de cada barra no gráfico
    for p in ax.patches:
        
        # Obtém as coordenadas x do retângulo da barra
        x = p.get_bbox().get_points()[:,0] 
        
        # Obtém a coordenada y do topo do retângulo da barra
        y = p.get_bbox().get_points()[1,1] 
        
        # Anota a porcentagem acima da barra
        ax.annotate('{:.1f}%'.format(100. * y / ncount), (x.mean(), y), ha = 'center', va = 'bottom') 
    
    # Define o título do gráfico com base na presença ou ausência da variável de agrupamento (hue)
    if not hue:
        
        # Sem variável de agrupamento
        ax.set_title(df[feature].describe().name + ' Análise', size = 13, pad = 15) 
        
    else:
        
        # Com variável de agrupamento  
        ax.set_title(df[feature].describe().name + ' Analisado Por ' + hue, size = 13, pad = 15) 
    
    # Se um título personalizado foi fornecido, ele é definido aqui
    if title != '':
        ax.set_title(title)  
    
    # Ajusta o layout do gráfico para evitar sobreposições de elementos gráficos
    plt.tight_layout()

# %%
# Define uma função para criar um gráfico de barras
def vendas_bar_plot(x, y, df, colors = 'Wistia_r', hue = False, ax = None, value = False, title = ''):
    
    # Tenta calcular o total da variável y, se falhar, calcula o total da variável x
    try:
        
        # Calcula o total dos valores da coluna y
        ncount = sum(df[y]) 
        
    except:
        
        # Calcula o total dos valores da coluna x em caso de erro com y
        ncount = sum(df[x]) 

    # Cria um gráfico de barras com ou sem uma variável de agrupamento (hue)
    if hue != False:
        
        # Com variável de agrupamento
        ax = sns.barplot(x = x, y = y, data = df, palette = colors, hue = hue, ax = ax, ci = None) 
        
    else:
        
        # Sem variável de agrupamento
        ax = sns.barplot(x = x, y = y, data = df, palette = colors, ax = ax, ci = None) 

    # Chama a função para formatar as bordas do gráfico 
    vendas_format_spines(ax)

    # Anota o valor ou a porcentagem sobre cada barra no gráfico
    for p in ax.patches:
        
        # Obtém as coordenadas x do retângulo da barra
        xp = p.get_bbox().get_points()[:,0] 
        
        # Obtém a coordenada y do topo do retângulo da barra
        yp = p.get_bbox().get_points()[1,1] 
        
        # Se verdadeiro 
        if value:
            
            # Anota o valor em milhares se value=True
            ax.annotate('{:.2f}k'.format(yp / 1000), (xp.mean(), yp), ha = 'center', va = 'bottom') 
            
        else:
            
            # Anota a porcentagem se value=False
            ax.annotate('{:.1f}%'.format(100. * yp / ncount), (xp.mean(), yp), ha = 'center', va = 'bottom') 
            
    # Define o título do gráfico com base na presença ou ausência da variável de agrupamento (hue)
    if not hue:
        
        # Sem variável de agrupamento
        ax.set_title(df[x].describe().name + ' Análise', size = 12, pad = 15) 
        
    else:
        
        # Com variável de agrupamento
        ax.set_title(df[x].describe().name + ' Analisado Por ' + hue, size = 12, pad = 15) 
    
    # Se um título personalizado foi fornecido, ele é definido aqui
    if title != '':
        
        # Define o título personalizado
        ax.set_title(title) 
    
    # Ajusta o layout do gráfico para evitar sobreposições de elementos gráficos
    plt.tight_layout()

# %% [markdown]
# ## Cena 1 - Evolução das Vendas ao Longo do Tempo

# %%
# Copia o dataset
df = df_vendas.copy()

# %%
# Colunas
df.columns
# Out:
# Index(['order_id', 'order_id3', 'customer_id3', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'order_item_id', 'product_id3',
#        'seller_id3', 'shipping_limit_date', 'price', 'freight_value',
#        'payment_sequential', 'payment_type', 'payment_installments',
#        'payment_value', 'review_id', 'review_id3', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'product_id',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'customer_id', 'customer_unique_id', 'customer_uniqueid3',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state',
#        'product_category_name_english', 'review_response_time',
#        'order_purchase_year', 'order_purchase_month',
#        'order_purchase_dayofweek', 'order_purchase_hour', 'order_purchase_day',
#        'order_purchase_mon'],
#       dtype='object')

# %% [markdown]
# ### Pergunta 1.1 - Como Foi a Performance de Vendas Por Ano (em Termos Percentuais)?

# %%
# Checa o total de registros por ano
df.order_purchase_year.value_counts()
# Out:
# order_purchase_year
# 2018    63199
# 2017    52994
# 2016      388
# Name: count, dtype: int64

# %%
# Cria datasets para cada ano
df_2016 = df.query('order_purchase_year=="2016"')
df_2017 = df.query('order_purchase_year=="2017"')
df_2018 = df.query('order_purchase_year=="2018"')

# %%
# Total de Pedidos Por Ano
fig, axs = plt.subplots(1, 1, figsize = (21, 8))
vendas_count_plot(feature = 'order_purchase_year', 
               df = df, 
               ax = axs, 
               title = 'Total de Pedidos Por Ano')
plt.show();

# %% [markdown]
# ### Pergunta 1.2 - Como Foi a Performance de Vendas de Cada Mês em Cada Ano (em Termos Percentuais)?

# %%
# Total de Pedidos Por Mês e Por Ano
fig, axs = plt.subplots(1, 1, figsize = (20, 8))
vendas_count_plot(feature = 'order_purchase_year', 
               df = df, 
               ax = axs, 
               hue = 'order_purchase_month', 
               title = 'Total de Pedidos Por Mês')
plt.show();

# %% [markdown]
# ### Pergunta 1.3 - Como Foi a Performance de Vendas Por Dia da Semana em Cada Ano (em Termos Percentuais)?

# %%
# Total de Pedidos Por Dia da Semana em Cada Ano
fig, axs = plt.subplots(1, 1, figsize = (21, 8))
vendas_count_plot(feature = 'order_purchase_year', 
               df = df, 
               ax = axs, 
               hue = 'order_purchase_dayofweek', 
               title = 'Total de Pedidos Por Dia da Semana')
plt.show();

# %% [markdown]
# ATENÇÃO: O primeiro dia da semana é segunda-feira (índice zero) nesse conjunto de dados.

# %% [markdown]
# ### Pergunta 1.4 - Responda a Pergunta 2 em Termos Absolutos

# %%
# Agrupamento por vendas anuais e mensais
df_ytsales = df.groupby(['order_purchase_year', 'order_purchase_month'], 
                        as_index = False).sum().loc[:, ['order_purchase_year', 
                                                        'order_purchase_month', 
                                                        'payment_value']]

# %%
# Prepara os dataframes
df_s2016 = df_ytsales[df_ytsales['order_purchase_year']==2016]
df_s2017 = df_ytsales[df_ytsales['order_purchase_year']==2017]
df_s2018 = df_ytsales[df_ytsales['order_purchase_year']==2018]

# %%
# Total de Vendas Por Mês em 2016 (Termos Absolutos)
fig, axs = plt.subplots(1, 1, figsize = (21, 7))
vendas_bar_plot(x = 'order_purchase_month', y = 'payment_value', df = df_s2016, ax = axs, value = True)
axs.set_title('Total de Vendas Por Mês em 2016 (Termos Absolutos)')
plt.xticks(np.arange(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Set', 'Out', 'Nov', 'Dez'])
plt.show()

# %%
# Total de Vendas Por Mês em 2017 (Termos Absolutos)
fig, axs = plt.subplots(1, 1, figsize = (21, 7))
vendas_bar_plot(x = 'order_purchase_month', y = 'payment_value', df = df_s2017, ax = axs, value = True)
axs.set_title('Total de Vendas Por Mês em 2017 (Termos Absolutos)')
plt.xticks(np.arange(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Set', 'Out', 'Nov', 'Dez'])
plt.show()

# %%
# Total de Vendas Por Mês em 2018 (Termos Absolutos)
fig, axs = plt.subplots(1, 1, figsize = (21, 7))
vendas_bar_plot(x = 'order_purchase_month', y = 'payment_value', df = df_s2018, ax = axs, value = True)
axs.set_title('Total de Vendas Por Mês em 2018 (Termos Absolutos)', pad = 10)
plt.xticks(np.arange(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Set', 'Out', 'Nov', 'Dez'])
plt.show()

# %% [markdown]
# ### Pergunta 1.5 - Demonstre a Linha do Tempo da Evolução da Performance de Vendas

# %%
# Alterando o atributo de mês para ordenação correta
df_ytsales['order_purchase_month'] = df_ytsales['order_purchase_month'].astype(str).apply(lambda x: '0' + x if len(x) == 1 else x)

# %%
# Criando nova coluna ano-mês
df_ytsales['month_year'] = df_ytsales['order_purchase_year'].astype(str) + '-' + df_ytsales['order_purchase_month'].astype(str)
df_ytsales['order_purchase_month'] = df_ytsales['order_purchase_month'].astype(int)

# %%
# Evolução das Vendas ao Longo do Tempo 

# Primeiro gráfico
fig, ax = plt.subplots(figsize = (14, 4.5))
ax = sns.lineplot(x = 'month_year', y = 'payment_value', data = df_ytsales.iloc[:-1, :])
vendas_format_spines(ax, right_border = False)
ax.tick_params(axis = 'x', labelrotation = 90)
ax.set_title('Evolução das Vendas ao Longo do Tempo')
plt.show()

# Segundo gráfico
fig, ax = plt.subplots(figsize = (14, 4.5))
ax = sns.lineplot(x = 'order_purchase_month', y = 'payment_value', data = df_s2016, label = '2016')
ax = sns.lineplot(x = 'order_purchase_month', y = 'payment_value', data = df_s2017, label = '2017')
ax = sns.lineplot(x = 'order_purchase_month', y = 'payment_value', data = df_s2018, label = '2018')
vendas_format_spines(ax, right_border = False)
ax.set_title('Evolução das Vendas ao Longo do Tempo')
plt.xticks(np.arange(12), ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
plt.show()

# %% [markdown]
# ### Pergunta 1.6 - Matriz de Comportamento de Compra do Cliente Por Hora do Dia

# %%
# Comportamento do cliente 
purchase_count = df.groupby(['order_purchase_day', 'order_purchase_hour']).count()['price'].unstack()
plt.figure(figsize = (22,7))
sns.heatmap(purchase_count.reindex(index = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']), 
            cmap = "YlOrRd", 
            annot = True, 
            fmt = "d", 
            linewidths = 0.2)
plt.show()

# %%
# %reload_ext watermark
# %watermark -a "Silmara Basso"
# Out:
# Author: Silmara Basso

# %%
#%watermark -v -m
# Out:
# Python implementation: CPython
# Python version       : 3.13.6
# IPython version      : 9.4.0
#
# Compiler    : Clang 15.0.0 (clang-1500.3.9.4)
# OS          : Darwin
# Release     : 23.2.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 16
# Architecture: 64bit

# %%
#%watermark --iversions
# Out:
# matplotlib: 3.10.3
# pandas    : 2.3.1
# seaborn   : 0.13.2
# numpy     : 2.3.1

# %% [markdown]
# # Fim
